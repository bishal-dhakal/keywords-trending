# %%
# !pip install pytrends

# %%
import pandas as pd
from pytrends.request import TrendReq
import matplotlib.pyplot as plt
trends = TrendReq()

# %%
trends.build_payload(kw_list=['Football'])
data = trends.interest_by_region()
print(data.sample(10))
# Out:
#             Football
# geoName
# Lesotho            0
# Hong Kong         10
# Aruba              0
# Belgium            8
# Brunei             0
# Mauritania         0
# Iraq               0
# Liberia            0
# Italy              4
# Niger              0

# %%
df = data.sample(15)
df.reset_index().plot(x="geoName", y="Football", figsize=(120,16), kind="bar")
plt.show()

# %%
data = trends.trending_searches(pn="football")
print(data.head(10))
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_5588\3105511566.py in <module>
# ----> 1 data = trends.trending_searches(pn="football")
#       2 print(data.head(10))
#
# ~\anaconda3\lib\site-packages\pytrends\request.py in trending_searches(self, pn)
#     472         # forms become obsolete due to the new TRENDING_SEARCHES_URL
#     473         # forms = {'ajax': 1, 'pn': pn, 'htd': '', 'htv': 'l'}
# --> 474         req_json = self._get_data(
#     475             url=TrendReq.TRENDING_SEARCHES_URL,
#     476             method=TrendReq.GET_METHOD
#
# KeyError: 'football'
